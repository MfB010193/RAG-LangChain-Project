# %%
# rag_faiss_final.ipynb
import os
import os

# Load Groq API key from environment variable
api_key = os.environ.get("GROQ_API_KEY")

if not api_key:
    raise ValueError("Please set the GROQ_API_KEY environment variable before running the notebook")

# %%
from langchain_community.document_loaders import PyPDFLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_community.vectorstores import FAISS
from langchain_core.prompts import PromptTemplate
from langchain_core.runnables import RunnableLambda, RunnablePassthrough
from langchain_community.embeddings import HuggingFaceEmbeddings
from langchain_groq import ChatGroq

# %%
def build_rag_pipeline(pdf_path="Concept Note.pdf"):
    # 1. load pdf
    loader = PyPDFLoader(pdf_path)
    docs = loader.load()

    # 2. split into chunks
    splitter = RecursiveCharacterTextSplitter(chunk_size=800, chunk_overlap=100)
    chunks = splitter.split_documents(docs)

    # 3. embeddings (local, free)
    emb = HuggingFaceEmbeddings(model_name="sentence-transformers/all-MiniLM-L6-v2")

    # 4. FAISS vector DB
    db = FAISS.from_documents(chunks, emb)

    # 5. retriever
    retriever = db.as_retriever(search_kwargs={"k": 3})

    # 6. prompt template
    prompt = PromptTemplate(
        input_variables=["context", "question"],
        template="""
You are an expert assistant. Use ONLY the context below to answer the question.

Context:
{context}

Question:
{question}

Answer:
"""
    )
    # 7. LLM (choose currently supported Groq model)
    llm = ChatGroq(model="llama-3.1-8b-instant")  # use the model that works for your key

    # 8. build runnable RAG pipeline
    def format_docs(docs):
        return "\n\n".join([d.page_content for d in docs])

    rag_chain = (
        {
            "context": retriever | RunnableLambda(format_docs),
            "question": RunnablePassthrough()
        }
        | prompt
        | llm
    )

    return rag_chain, retriever, chunks

def ask_question(rag_chain, query):
    res = rag_chain.invoke(query)
    return res.content

def main():
    rag_chain, retriever, chunks = build_rag_pipeline("Concept Note.pdf")
    print(f"Loaded {len(chunks)} chunks. Retriever k={retriever.search_kwargs.get('k',3)}")

    # Demo queries
    examples = [
        "What is the main purpose of the Concept Note?",
        "List the 3 implementation steps mentioned in the Concept Note.",
        "What budget items are mentioned in the Concept Note?"
    ]

    for q in examples:
        print("\n>>> QUERY:", q)
        answer = ask_question(rag_chain, q)
        print("ANSWER:\n", answer)

    # Show what happens without retrieval: (LLM-only baseline)
    print("\n--- LLM-only baseline (no retrieval) ---")
    llm = ChatGroq(model="llama-3.1-8b-instant")
    baseline = llm.invoke("What is the main purpose of the Concept Note?").content
    print("LLM-only answer:\n", baseline)

    print("\nDone.")

if __name__ == "__main__":
    main()
# Out:
# Loaded 10 chunks. Retriever k=3
#
# >>> QUERY: What is the main purpose of the Concept Note?
# ANSWER:
#  The main purpose of the Concept Note is to propose a project for model development that involves implementing a Physics-Informed Neural Network (PINN) to integrate with physical constraints derived from hydrological and atmospheric equations governing rainfall processes.
#
# >>> QUERY: List the 3 implementation steps mentioned in the Concept Note.
# ANSWER:
#  Based on the provided context, the 3 implementation steps mentioned in the Concept Note are:
#
# 1. Implement a PINN that integrates with physical constraints derived from hydrological and atmospheric equations governing rainfall process.
# 2. Compare performance with conventional ML models like LSTMs, Random Forests, and Purely physics-based downscaling methods.
# 3. Support water resource management and agricultural planning in the Blue Nile Basin through practical contributions.
#
# >>> QUERY: What budget items are mentioned in the Concept Note?
# ANSWER:
#  There are no budget items mentioned in the provided context.
#
# --- LLM-only baseline (no retrieval) ---
# LLM-only answer:
#  A Concept Note is a brief document that outlines the main objectives, goals, and expected outcomes of a project or program. The main purpose of a Concept Note is to provide a concise overview of a proposed project or initiative, highlighting its key aspects, such as:
#
# 1. Background and context
# 2. Problem statement or need
# 3. Objectives and expected outcomes
# 4. Methodology and approach
# 5. Expected impact and sustainability
# 6. Budget and resources required
#
# The main purposes of a Concept Note are:
#
# 1. To introduce and explain the proposed project or initiative
# 2. To demonstrate its relevance and alignment with the goals and objectives of the funding agency or organization
# 3. To provide a clear understanding of the project's scope, objectives, and expected outcomes
# 4. To showcase the project's potential for impact and sustainability
# 5. To support the development of a full proposal or funding application.
#
# A Concept Note is often used in the early stages of project development, as a starting point for further planning and development, or as a preliminary document to be submitted to a funding agency or organization to gauge interest and support for a project.
#
# Done.
